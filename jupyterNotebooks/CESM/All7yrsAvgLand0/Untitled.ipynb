# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds = Dataset('/scratch/srai6/EddyKillingPaper3/CESM/all7yrs_land0/gridFromWilber.nc')
ds2 = Dataset('/scratch/srai6/EddyKillingPaper3/CESM/all7yrs_land0/tripoleGridCreated.nc')

# %%
ds.variables.keys()
# Out:
# dict_keys(['ANGLE', 'ANGLET', 'DXT', 'DXU', 'DYT', 'DYU', 'HT', 'HTE', 'HTN', 'HU', 'HUS', 'HUW', 'KMT', 'KMU', 'REGION_MASK', 'T0_Kelvin', 'TAREA', 'TLAT', 'TLONG', 'U1_1', 'UAREA', 'ULAT', 'ULONG', 'cp_air', 'cp_sw', 'days_in_norm_year', 'dz', 'dzw', 'fwflux_factor', 'grav', 'heat_to_PW', 'hflux_factor', 'latent_heat_fusion', 'latent_heat_vapor', 'mass_to_Sv', 'momentum_factor', 'nsurface_t', 'nsurface_u', 'ocn_ref_salinity', 'omega', 'ppt_to_salt', 'radius', 'rho_air', 'rho_fw', 'rho_sw', 'salinity_factor', 'salt_to_Svppt', 'salt_to_mmday', 'salt_to_ppt', 'sea_ice_salinity', 'sflux_factor', 'sound', 'stefan_boltzmann', 'time', 'time_bound', 'vonkar', 'z_t', 'z_t_150m', 'z_w', 'z_w_bot', 'z_w_top'])

# %%
dxu = np.array(ds.variables['ULAT'])
dxu2 = np.array(ds2.variables['ULAT'])

# %%
dxu.shape
# Out:
# (2400, 3600)

# %%
plt.pcolormesh(dxu -dxu2)
plt.colorbar()

# %%
ds
